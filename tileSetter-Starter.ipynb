# %%
from pyleSetter import *
# Out:
# HTML Updated!
#
# Loaded name generator named 'bb' .
# To generate more names, use 'nb_refresh(bb)')
# create new name generator using nb.nameGen().

# %%
# Re-run this cell to generate new names
refresh(bb, notebook=True)
# Out:
# <style>a {  float:left;  padding:0px;  text-decoration:none;  overflow:hidden;  font:11px Tahoma;  background-repeat:no-repeat;  }.pet {  height:50px;  width:50px;  float:left;}a {  float:left;  padding:0px;  margin:1px;  color:#71AAC9;  border-radius:5px;  background: #fff;}a:hover {  background-color:#71AAC9;  border:1px solid #71AAC9;  margin:0px;  }a:visited {  background: #ccc;}a p {  display:block;  text-align:center!important;  margin-top:0px;  padding:0px;  color: #71AAC9;  background:#fff;}.pet:hover p {  opacity:0.5;  color: #3A3A44;}a:visited p {  color:#5D71A3;  font:11px Arial;  background:#ccc;  }.pet img {  margin-top:0px;  height:40px;  display:block;  margin:auto;  }/**.pet a {  color:#71AAC9;  text-decoration:none;  display:block;  width:55px;  background:#3A3A44;  }**//**.pet p {    color:#71AAC9;    text-decoration:none;    text-align:center;    display:block;    width:55px;    background:#3A3A44;}**/.petgroup h2 {  font:18px Tahoma;  margin:5px auto 5px;  padding:5px;  letter-spacing:1px;  border-left: 15px solid #aaeeee;  background-color:#71AAC9;  color:#fff;  text-align:left;}.petgroup {  float:left;  width:100%;}</style><div style="float:left;padding-left:50px;"><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th># of names</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>6 Letters</th>
#       <td>100</td>
#     </tr>
#     <tr>
#       <th>7 Letters</th>
#       <td>100</td>
#     </tr>
#     <tr>
#       <th>8 Letters</th>
#       <td>100</td>
#     </tr>
#     <tr>
#       <th>Total Names</th>
#       <td>300</td>
#     </tr>
#   </tbody>
# </table>Last Updated @07:00:52 PM</div><div style="float:left;margin-top:0px;padding-left:75px;"><br><b>Generator:</b><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>pieces</th>
#       <th>Lmin</th>
#       <th>Lmax</th>
#       <th>regex</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>bit*</td>
#       <td>3</td>
#       <td>4</td>
#       <td>[a-z][a-z][a-z].</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>bit*</td>
#       <td>3</td>
#       <td>4</td>
#       <td>[a-z][a-z][a-z].</td>
#     </tr>
#   </tbody>
# </table></div><div class="petgroup"><h2>6 Letters</h2><a href="http://neopets.com/~Anrhum" style=""><div style="background: url('http://pets.neopets.com/cpn/Anrhum/1/1.png');" class="pet"><p>Anrhum</p></div></a><a href="http://neopets.com/~Artkni" style=""><div style="background: url('http://pets.neopets.com/cpn/Artkni/1/1.png');" class="pet"><p>Artkni</p></div></a><a href="http://neopets.com/~Auyzaa" style=""><div style="background: url('http://pets.neopets.com/cpn/Auyzaa/1/1.png');" class="pet"><p>Auyzaa</p></div></a><a href="http://neopets.com/~Avpioy" style=""><div style="background: url('http://pets.neopets.com/cpn/Avpioy/1/1.png');" class="pet"><p>Avpioy</p></div></a><a href="http://neopets.com/~Avrokl" style=""><div style="background: url('http://pets.neopets.com/cpn/Avrokl/1/1.png');" class="pet"><p>Avrokl</p></div></a><a href="http://neopets.com/~Azwegi" style=""><div style="background: url('http://pets.neopets.com/cpn/Azwegi/1/1.png');" class="pet"><p>Azwegi</p></div></a><a href="http://neopets.com/~Azxvep" style=""><div style="background: url('http://pets.neopets.com/cpn/Azxvep/1/1.png');" class="pet"><p>Azxvep</p></div></a><a href="http://neopets.com/~Boowiq" style=""><div style="background: url('http://pets.neopets.com/cpn/Boowiq/1/1.png');" class="pet"><p>Boowiq</p></div></a><a href="http://neopets.com/~Brbsil" style=""><div style="background: url('http://pets.neopets.com/cpn/Brbsil/1/1.png');" class="pet"><p>Brbsil</p></div></a><a href="http://neopets.com/~Brrbux" style=""><div style="background: url('http://pets.neopets.com/cpn/Brrbux/1/1.png');" class="pet"><p>Brrbux</p></div></a><a href="http://neopets.com/~Buhsei" style=""><div style="background: url('http://pets.neopets.com/cpn/Buhsei/1/1.png');" class="pet"><p>Buhsei</p></div></a><a href="http://neopets.com/~Bujplj" style=""><div style="background: url('http://pets.neopets.com/cpn/Bujplj/1/1.png');" class="pet"><p>Bujplj</p></div></a><a href="http://neopets.com/~Chirak" style=""><div style="background: url('http://pets.neopets.com/cpn/Chirak/1/1.png');" class="pet"><p>Chirak</p></div></a><a href="http://neopets.com/~Chtyar" style=""><div style="background: url('http://pets.neopets.com/cpn/Chtyar/1/1.png');" class="pet"><p>Chtyar</p></div></a><a href="http://neopets.com/~Cisuty" style=""><div style="background: url('http://pets.neopets.com/cpn/Cisuty/1/1.png');" class="pet"><p>Cisuty</p></div></a><a href="http://neopets.com/~Civept" style=""><div style="background: url('http://pets.neopets.com/cpn/Civept/1/1.png');" class="pet"><p>Civept</p></div></a><a href="http://neopets.com/~Clhrym" style=""><div style="background: url('http://pets.neopets.com/cpn/Clhrym/1/1.png');" class="pet"><p>Clhrym</p></div></a><a href="http://neopets.com/~Clzpiq" style=""><div style="background: url('http://pets.neopets.com/cpn/Clzpiq/1/1.png');" class="pet"><p>Clzpiq</p></div></a><a href="http://neopets.com/~Cofcik" style=""><div style="background: url('http://pets.neopets.com/cpn/Cofcik/1/1.png');" class="pet"><p>Cofcik</p></div></a><a href="http://neopets.com/~Crgstf" style=""><div style="background: url('http://pets.neopets.com/cpn/Crgstf/1/1.png');" class="pet"><p>Crgstf</p></div></a><a href="http://neopets.com/~Crmkli" style=""><div style="background: url('http://pets.neopets.com/cpn/Crmkli/1/1.png');" class="pet"><p>Crmkli</p></div></a><a href="http://neopets.com/~Crvucc" style=""><div style="background: url('http://pets.neopets.com/cpn/Crvucc/1/1.png');" class="pet"><p>Crvucc</p></div></a><a href="http://neopets.com/~Cuhila" style=""><div style="background: url('http://pets.neopets.com/cpn/Cuhila/1/1.png');" class="pet"><p>Cuhila</p></div></a><a href="http://neopets.com/~Cusebr" style=""><div style="background: url('http://pets.neopets.com/cpn/Cusebr/1/1.png');" class="pet"><p>Cusebr</p></div></a><a href="http://neopets.com/~Doxlke" style=""><div style="background: url('http://pets.neopets.com/cpn/Doxlke/1/1.png');" class="pet"><p>Doxlke</p></div></a><a href="http://neope ...

# %%
#nb.export_pres(nb.w_s) # run this cell to export prefixes
